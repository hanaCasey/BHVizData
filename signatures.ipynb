# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/bhr1.csv', error_bad_lines=False, sep=';')
columns = df1.columns
df2 = pd.read_csv('data/bhr2.csv', names = columns, error_bad_lines=False, sep=';')
df = pd.concat([df1, df2])
# Out:
# C:\Users\hanna\AppData\Local\Temp/ipykernel_4180/891959089.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df1 = pd.read_csv('data/bhr1.csv', error_bad_lines=False, sep=';')
# C:\Users\hanna\AppData\Local\Temp/ipykernel_4180/891959089.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('data/bhr2.csv', names = columns, error_bad_lines=False, sep=';')

# %%
df
# Out:
#       lev      sys numbis                                               text  \
# 0       1    S xxx    yyy                           ...Bibliotheca Hertziana
# 1       1    S xxx    yyy                  ...Systematischer Standortkatalog
# 2       1       A     NaN                                    ...Handbücherei
# 3       2      Aa     NaN                  ......Allgemeine Nachschlagewerke
# 4       3   Aa xxx    yyy                                    .........Lexika
# ...   ...      ...    ...                                                ...
# 5960    5  Zt 9630    NaN  ...............idem (= Neuzeit (nach 1500)), n...
# 5961    5  Zt 9660    NaN  ...............idem (= Neuzeit (nach 1500)), n...
# 5962    5  Zt 9700    NaN          ...............19. und 20. Jh., allgemein
# 5963    5  Zt 9730    NaN  ...............idem (= 19. und 20. Jh.), nur k...
# 5964    5  Zt 9760    NaN  ...............idem (= 19. und 20. Jh.), nur p...
#
#        vw
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 5960  NaN
# 5961  NaN
# 5962  NaN
# 5963  NaN
# 5964  NaN
#
# [11963 rows x 5 columns]

# %% [markdown]
# ## Cleaning

# %% [markdown]
# #### Text

# %%
# getting rid of the ... in the texts
df["text"] = df["text"].str.replace(r'\.{3,}', '')
# Out:
# C:\Users\hanna\AppData\Local\Temp/ipykernel_4180/1185189639.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["text"] = df["text"].str.replace(r'\.{3,}', '')

# %%
df
# Out:
#       lev      sys numbis                                              text  \
# 0       1    S xxx    yyy                             Bibliotheca Hertziana
# 1       1    S xxx    yyy                    Systematischer Standortkatalog
# 2       1       A     NaN                                      Handbücherei
# 3       2      Aa     NaN                       Allgemeine Nachschlagewerke
# 4       3   Aa xxx    yyy                                            Lexika
# ...   ...      ...    ...                                               ...
# 5960    5  Zt 9630    NaN      idem (= Neuzeit (nach 1500)), nur katholisch
# 5961    5  Zt 9660    NaN  idem (= Neuzeit (nach 1500)), nur protestantisch
# 5962    5  Zt 9700    NaN                        19. und 20. Jh., allgemein
# 5963    5  Zt 9730    NaN          idem (= 19. und 20. Jh.), nur katholisch
# 5964    5  Zt 9760    NaN      idem (= 19. und 20. Jh.), nur protestantisch
#
#        vw
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 5960  NaN
# 5961  NaN
# 5962  NaN
# 5963  NaN
# 5964  NaN
#
# [11963 rows x 5 columns]

# %%
# resolve the idem thing

# %%
# import the rows with no particular signature
