# %%
import pandas as pd

# %%
path = 'data/01.json'
with open(path, encoding="utf8") as file: 
    content = file.read()
parsed = json.loads(content)  
#pop first layer of the records
parsed.update(parsed.pop('records'))

# %%
df = pd.DataFrame.from_dict(parsed, orient='index')

# %%
#Subject Access fields
df.filter(regex=("^6.*"))
# Out:
#                                                            610  \
# BV000023649  {'a': 'Deutsches Literaturarchiv Marbach', '0'...
# BV000024214                                                NaN
# BV000024767                                                NaN
# BV000025578                                                NaN
# BV000026429                                                NaN
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686      {'a': 'Basilica palladiana (Vicenza, Italy)'}
# BV001555100                                                NaN
#
#                                                            648  \
# BV000023649   {'a': 'Geschichte', '2': 'gnd', '9': 'rswk-swf'}
# BV000024214  {'a': 'Geschichte 1830-1848', '2': 'gnd', '9':...
# BV000024767  {'a': 'Weltgeschichte', '2': 'gnd', '9': 'rswk...
# BV000025578                                                NaN
# BV000026429                                                NaN
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563  {'a': 'Geschichte 1250-1816', '2': 'gnd', '9':...
# BV001554686  {'a': 'Geschichte -1580', '2': 'gnd', '9': 'rs...
# BV001555100                                                NaN
#
#                                      689  \
# BV000023649              {'5': 'DE-604'}
# BV000024214              {'5': 'DE-604'}
# BV000024767  {'8': '5|p', '5': 'DE-604'}
# BV000025578              {'5': 'DE-604'}
# BV000026429              {'5': 'DE-604'}
# ...                                  ...
# BV001554556                          NaN
# BV001554561                          NaN
# BV001554563              {'5': 'DE-604'}
# BV001554686    {'C': 'b', '5': 'DE-604'}
# BV001555100              {'5': 'DE-604'}
#
#                                                            600  \
# BV000023649                                                NaN
# BV000024214  {'a': 'Burckhardt, Jacob', 'd': '1818-1897', '...
# BV000024767  {'a': 'Burckhardt, Jacob', 'd': '1818-1897', '...
# BV000025578  {'a': 'Herzog, Werner', 'd': '1942-', '0': '(D...
# BV000026429  {'a': 'Rauzzini, Filippo', '0': '(DE-588)12110...
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686  {'a': 'Palladio, Andrea', 'd': '1508-1580', '0...
# BV001555100                                                NaN
#
#                                                            650  \
# BV000023649                                                NaN
# BV000024214  {'a': 'Kunstbetrachtung', '0': '(DE-588)412532...
# BV000024767  {'a': 'Weltgeschichte', '0': '(DE-588)4079158-...
# BV000025578                            {'a': 'German fiction'}
# BV000026429        {'a': 'Architecture, Rococo', 'z': 'Italy'}
# ...                                                        ...
# BV001554556                                {'a': 'Geschichte'}
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686  {'a': 'Architekturtheorie', '0': '(DE-588)4112...
# BV001555100  {'a': 'Kunstkritik', '0': '(DE-588)4033659-1',...
#
#                                                            651  \
# BV000023649                                                NaN
# BV000024214  {'a': 'Deutschland', '0': '(DE-588)4011882-4',...
# BV000024767                                                NaN
# BV000025578                                                NaN
# BV000026429                                   {'a': 'Italien'}
# ...                                                        ...
# BV001554556             {'a': 'Terni (Italy)', 'x': 'History'}
# BV001554561                             {'a': 'Rieti (Italy)'}
# BV001554563  {'a': 'Arezzo', '0': '(DE-588)4002888-4', '2':...
# BV001554686  {'a': 'Vicenza', '0': '(DE-588)4063445-0', '2'...
# BV001555100                                                NaN
#
#                                                            655  \
# BV000023649                                                NaN
# BV000024214                                                NaN
# BV000024767  {'0': '(DE-588)4143413-4', 'a': 'Aufsatzsammlu...
# BV000025578                                                NaN
# BV000026429  {'0': '(DE-588)4016928-5', 'a': 'Festschrift',...
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686                                                NaN
# BV001555100                                                NaN
#
#                                                            688  \
# BV000023649                                                NaN
# BV000024214                                                NaN
# BV000024767  {'a': 'Jacob Burckhardt (1818 - 1897)', '0': '...
# BV000025578                                                NaN
# BV000026429                                                NaN
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686                                                NaN
# BV001555100                                                NaN
#
#                                                            630  \
# BV000023649                                                NaN
# BV000024214                                                NaN
# BV000024767                                                NaN
# BV000025578  {'a': 'Fitzcarraldo', '0': '(DE-588)4154490-0'...
# BV000026429                                                NaN
# ...                                                        ...
# BV001554556                                                NaN
# BV001554561                                                NaN
# BV001554563                                                NaN
# BV001554686                                                NaN
# BV001555100                                                NaN
#
#                                    653  611
# BV000023649                        NaN  NaN
# BV000024214                        NaN  NaN
# BV000024767                        NaN  NaN
# BV000025578                        NaN  NaN
# BV000026429                        NaN  NaN
# ...                                ...  ...
# BV001554556                        NaN  NaN
# BV001554561                        NaN  NaN
# BV001554563                        NaN  NaN
# BV001554686  {'a': 'Palladio, Andrea'}  NaN
# BV001555100                        NaN  NaN
#
# [6008 rows x 11 columns]

# %%
df['648'].astype(str).str.extract(r'(?<=\'a\':\s\')(.*?)(?=\')')
# Out:
#                                 0
# BV000023649            Geschichte
# BV000024214  Geschichte 1830-1848
# BV000024767        Weltgeschichte
# BV000025578                   NaN
# BV000026429                   NaN
# ...                           ...
# BV001554556                   NaN
# BV001554561                   NaN
# BV001554563  Geschichte 1250-1816
# BV001554686      Geschichte -1580
# BV001555100                   NaN
#
# [6008 rows x 1 columns]

# %% [markdown]
# ### List of columns that we might be interested in
# 041: 'language_code'
# 049: 'holdings'
# 100: 'author_person'
# 110: 'author_corporate'
# 245: 'title'
# 264: 'publication'
# 300: 'physical_description'
# 600: 'subject_personal'
# 611: 'subject_corporate'
# 648: 'subject_chronological'
# 650: 'subject_topical'
# keep all the 6XX for topics
