# %%
import pandas as pd
import json
import re
import csv

# %%
#features of interest and their marc21 code
columns = { 
'001': 'id',
'041' : 'language_code',
'049': 'holdings',
'100': 'author_person',
'110': 'author_corporate',
'111': 'author_meeting',
'111': 'author_uniform',
'245': 'title',
'264': 'publication',
'300': 'physical_description',
'600': 'subject_personal',
'610': 'subject_corporate',
'611': 'subject_meeting',
'630': 'subject_uniform_title',
'647': 'subject_named_event',
'648': 'subject_chronological',
'650': 'subject_topical',
'651': 'subject_geographic'
          }

# %%
columns.values()
# Out:
# dict_values(['id', 'language_code', 'holdings', 'author_person', 'author_corporate', 'author_uniform', 'title', 'publication', 'physical_description', 'subject_personal', 'subject_corporate', 'subject_meeting', 'subject_uniform_title', 'subject_named_event', 'subject_chronological', 'subject_topical', 'subject_geographic'])

# %%
path = 'data/b3kat_export_202211_teil01.json'
with open(path, encoding="utf8") as f: 
    data = json.load(f)
    for record in data['records']:
        
        print(record.values())
        #for d in record['keywords']:
            #print(d['word'])
# Out:
# dict_values(['BV000023649', ['ger'], 'Deutsches Literaturarchiv, Schiller-Nationalmuseum', 'die Institute der Deutschen Schillergesellschaft in Marbach am Neckar', 'vorgestellt von den Mitarbeitern', 'Marbach a. Neckar', '1982', '181, 16 S.', [{'word': 'Deutsches Literaturarchiv Marbach', 'type': 'b', 'gnd': '(DE-588)10155895-8'}], 'BV040655651', 'Marbacher Schriften'])
# dict_values(['BV000024214', ['ger'], [{'name': 'Schlink, Wilhelm', 'role': 'Verfasser', 'gnd': '(DE-588)115437320'}], 'Jacob Burckhardt und die Kunsterwartung im Vormärz', 'Wilhelm Schlink', 'Wiesbaden', 'Steiner', '1982', '27 S.', 'Ill.', [{'word': 'Burckhardt, Jacob', 'date': '1818-1897', 'type': 'p', 'gnd': '(DE-588)11851752X'}, {'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Historienmalerei', 'type': 's', 'gnd': '(DE-588)4025097-0'}], 'BV000000154', 'Frankfurter historische Vorträge'])
# dict_values(['BV000024767', ['ger'], [{'name': 'Burckhardt, Jacob'}], 'Über das Studium der Geschichte', 'der Text der Weltgeschichtlichen Betrachtungen auf Grund der Vorarbeiten von Ernst Ziegler', 'Jacob Burckhardt. Nach den Handschriften herausgegeben von Peter Ganz', 'München', 'Verlag C.H.Beck', '1982', '582 Seiten', [{'name': 'Ganz, Peter F.', 'role': 'edt', 'gnd': '(DE-588)105692999'}, {'name': 'Ziegler, Ernst', 'role': 'oth', 'gnd': '(DE-588)120543931'}], [{'word': 'Geschichtsstudium', 'type': 's', 'gnd': '(DE-588)4131152-8'}, {'word': 'Burckhardt, Jacob', 'date': '1818-1897', 'type': 'p', 'gnd': '(DE-588)11851752X'}]])
# dict_values(['BV000025578', ['ger'], [{'name': 'Herzog, Werner', 'role': 'Verfasser', 'gnd': '(DE-588)118550276'}], 'Fitzcarraldo', 'Erzählung', 'Werner Herzog', 'München u.a.', 'Hanser', '1982', '164 S.', 'Kt.', [{'word': 'Fitzcarraldo', 'type': 'u', 'gnd': '(DE-588)4154490-0'}, {'word': 'Herzog, Werner', 'date': '1942-', 'type': 'p', 'gnd': '(DE-588)118550276'}]])
# dict_values(['BV000026429', ['ita'], [{'name': 'Rotili, Mario', 'role': 'Verfasser', 'gnd': '(DE-588)1143711246'}], 'Filippo Raguzzini nel terzo centenario della nascita', 'precisazioni, aggiunte e prospettive di studio', 'Napoli', 'Soc. Ed. Napoletana', '1982', '69 S.', 'zahlr. Ill.', [{'name': 'Rauzzini, Filippo', 'role': 'hnr', 'gnd': '(DE-588)121103455'}], [{'word': 'Rauzzini, Filippo', 'type': 'p', 'gnd': '(DE-588)121103455'}], 'BV000000758', "Studi e testi di storia e critica dell'arte"])
# dict_values(['BV000026609', ['ger'], [{'name': 'Pfeiffer, Rudolf', 'role': 'Verfasser', 'gnd': '(DE-588)118740814'}], 'Die klassische Philologie von Petrarca bis Mommsen', 'Rudolf Pfeiffer', 'Deutsche Ausgabe', 'München', 'Verlag C.H.Beck', '1982', '260 Seiten', ['Fortsetzung von: Pfeiffer, Rudolf: Geschichte der klassischen Philologie'], [{'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Klassische Philologie', 'type': 's', 'gnd': '(DE-588)4164044-5'}, {'word': 'Petrarca, Francesco', 'date': '1304-1374', 'type': 'p', 'gnd': '(DE-588)118593234'}], 'A history of classical scholarship from 1300-1850'])
# dict_values(['BV000026897', ['ger'], [{'name': 'Wimmer, Otto', 'role': 'Verfasser', 'gnd': '(DE-588)1155247949'}], 'Lexikon der Namen und Heiligen', 'Otto Wimmer ; Hartmann Melzer', '4., neubearb. u. wesentlich erw. Aufl.', 'Innsbruck [u.a.]', 'Tyrolia-Verl.', '1982', '980 Seiten', '24 cm', ['Frühere Aufl. u.d.T.: Handbuch der Namen und Heiligen'], [{'name': 'Melzer, Hartmann', 'role': 'aut', 'gnd': '(DE-588)1165903385'}], [{'word': 'Personenname', 'type': 's', 'gnd': '(DE-588)4045285-2'}]])
# dict_values(['BV000027669', ['ita'], 'La croce del Pollaiolo', '[testo di Marco Collareta, schede di Donata Levi]', 'Firenze', 'Museo Nazionale del Bargello', '1982', '27 S.', 'zahlr. Ill.', [{'name': 'Collareta, Marco', 'role': 'oth', 'gnd': '(DE-588)134110765'}, {'name': 'Levi, Donata', 'role': 'oth', 'gnd': '(DE-588)136646506'}], [{'word': 'Del Pollaiuolo, Antonio', 'date': '1429-1498', 'type': 'p', 'gnd': '(DE-588)118638696'}, {'word': 'Kreuz', 'type': 's', 'gnd': '(DE-588)4033065-5'}, {'word': 'Museo Nazionale del Bargello', 'type': 'b', 'gnd': '(DE-588)131520-1'}], 'BV037477689', 'Lo specchio del Bargello'])
# dict_values(['BV000028059', ['ger'], 'Echternacher Sakramentar und Antiphonar', 'vollständige Faksimile-Ausgabe im Original-Format der Handschrift 1946 aus dem Besitz der Hessischen Landes- und Hochschulbibliothek Darmstadt', '[1]', 'Graz', 'Akad. Druck- und Verl.-Anst.', '1982', '278 Bl.', 'Ill.', [{'name': 'Staub, Kurt Hans', 'role': 'oth', 'gnd': '(DE-588)12935211X'}], [], 'BV002673900', 'Codices selecti'])
# dict_values(['BV000028061', ['ger'], 'Echternacher Sakramentar und Antiphonar', 'vollständige Faksimile-Ausgabe im Original-Format der Handschrift 1946 aus dem Besitz der Hessischen Landes- und Hochschulbibliothek Darmstadt', 'Kurt Hans Staub', '[2]', 'Graz', 'Akad. Druck- und Verl.-Anst.', '1982', 'VII, 234 S.', 'Ill.', [{'name': 'Staub, Kurt Hans', 'role': 'oth', 'gnd': '(DE-588)12935211X'}], [], 'BV002673900', 'Codices selecti'])
# dict_values(['BV000028770', ['ger'], [{'name': 'Rohr, René R. J.', 'role': 'Verfasser'}], 'Die Sonnenuhr', 'Geschichte, Theorie, Funktion', 'René R. J. Rohr', 'München', 'Callwey', '1982', '215 S.', 'zahlr. Ill. u. graph. Darst.', ['EST: Les cadrans solaires <dt.>. - Aus d. Franz. übers.'], [{'word': 'Sonnenuhr', 'type': 's', 'gnd': '(DE-588)4055589-6'}], 'Les cadrans solaires'])
# dict_values(['BV000028857', ['ger'], [{'name': 'Lankheit, Klaus', 'role': 'Verfasser', 'gnd': '(DE-588)11872648X'}], 'Die Modellsammlung der Porzellanmanufaktur Doccia', 'ein Dokument italienischer Barockplastik', 'Klaus Lankheit', 'München', 'Bruckmann', '1982', '240 S.', 'zahlr. Ill.', [{'word': 'Museo Richard Ginori della Manifattura di Doccia', 'type': 'b', 'gnd': '(DE-588)10031909-9'}, {'word': 'Porzellanplastik', 'type': 's', 'gnd': '(DE-588)4175411-6'}, {'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}], 'BV035416991', 'Italienische Forschungen'])
# dict_values(['BV000029509', ['lat'], 'Codex diplomaticus Amiatinus', 'Urkundenbuch der Abtei S. Salvatore am Montamiata ; von den Anfängen bis zum Papst Innozenz III. (736 - 1198)', 'im Auftrag des Deutschen Historischen Instituts in Rom bearb. von Wilhelm Kurze', '1', 'Tübingen', 'Niemeyer', '1974', 'XXVIII, 420 S.', [{'name': 'Kurze, Wilhelm', 'role': 'oth', 'gnd': '(DE-588)124362028'}], []])
# dict_values(['BV000029510', ['lat'], 'Codex diplomaticus Amiatinus', 'Urkundenbuch der Abtei S. Salvatore am Montamiata ; von den Anfängen bis zum Papst Innozenz III. (736 - 1198)', 'im Auftrag des Deutschen Historischen Instituts in Rom bearb. von Wilhelm Kurze', '2', 'Tübingen', 'Niemeyer', '1982', 'XIX, 391 S.', [{'name': 'Kurze, Wilhelm', 'role': 'oth', 'gnd': '(DE-588)124362028'}], []])
# dict_values(['BV000029648', ['fre'], [{'name': 'Moretti, Italo', 'role': 'Verfasser'}], 'Toscane romane', "Italo Moretti ; Renato Stopani. Traduit de l'italien par Norbert Vaillant. Photographies de Zodiaque. Les cartes et les plans et coupes ont été dessinés par Noël Deney ...", '[Paris]', 'Zodiaque', '[1982]', '361 S.', 'zahlr. Ill., Kt.', ['Aus d. Ital. übers.'], [{'name': 'Stopani, Renato', 'role': 'aut', 'gnd': '(DE-588)1059949695'}, {'name': 'Vaillant, Norbert', 'role': 'trl'}, {'name': 'Deney, Noël', 'role': 'ill'}], [{'word': 'Toskana', 'type': 'g', 'gnd': '(DE-588)4060485-8'}, {'word': 'Kirchenbau', 'type': 's', 'gnd': '(DE-588)4073436-5'}], 'BV000000883', 'La nuit des temps'])
# dict_values(['BV000029991', ['ger', 'fre', 'eng'], 'Glossarium artis', "Wörterbuch der Kunst ; dictionnaire des termes d'art ; dictionary of art terms", "Comité International d'Histoire de l'Art. Red.: Rudolf E. Huber", '5', '2., vollst. neu bearb. und erw. Aufl.', 'München [u.a.]', 'Saur', '1985', '278 S.', 'zahlr. Ill.', [{'name': 'Lodge, Ken', 'role': 'oth'}, {'name': 'Huber, Rudolf', 'role': 'oth', 'gnd': '(DE-588)117032239'}], [{'word': 'Treppe', 'type': 's', 'gnd': '(DE-588)4060816-5'}]])
# dict_values(['BV000030019', ['ger'], 'Katalog der Handbibliothek der Handschriftenabteilung', 'Bayerische Staatsbibliothek', '1', 'Wiesbaden', 'Reichert', '1981', '739 S.'])
# dict_values(['BV000030020', ['ger'], 'Katalog der Handbibliothek der Handschriftenabteilung', 'Bayerische Staatsbibliothek', '2', 'Wiesbaden', 'Reichert', '1981', '668 S.'])
# dict_values(['BV000030258', ['eng'], [{'name': 'Cheney, Christopher R.', 'role': 'Verfasser', 'gnd': '(DE-588)124058450'}], 'The papacy and England, 12th - 14th centuries', 'historical and legal studies', 'C. R. Cheney', 'London', 'Variorum Reprints', '1982', 'Getr. Zählung', [{'word': 'England', 'type': 'g', 'gnd': '(DE-588)4014770-8'}, {'word': 'Papst', 'type': 's', 'gnd': '(DE-588)4044561-6'}]])
# dict_values(['BV000030678', ['ger'], 'Goethe als Zeichner', 'mit zweihundertzwei Goethezeichnungen', 'Wolfgang Hecht. Hrsg. im Auftr. der Nationalen Forschungs- und Gedenkstätten der Klassischen Deutschen Literatur in Weimar', 'München', 'Beck', '1982', '247 S.', 'überw. Ill.', [{'name': 'Goethe, Johann Wolfgang von', 'role': 'oth', 'gnd': '(DE-588)118540238'}, {'name': 'Hecht, Wolfgang', 'role': 'oth', 'gnd': '(DE-588)137304587'}], [{'word': 'Goethe, Johann Wolfgang von', 'date': '1749-1832', 'type': 'p', 'gnd': '(DE-588)118540238'}, {'word': 'Zeichnung', 'type': 's', 'gnd': '(DE-588)4127900-1'}]])
# dict_values(['BV000030684', ['ger'], 'Graphik in Holland', 'Esaias und Jan van de Velde, Rembrandt, Ostade und ihr Kreis ; Radierung, Kupferstich, Schabkunst ; Staatliche Graphische Sammlung München, Ausstellung in der Neuen Pinakothek, 9. Juni bis 1. August 1982', '[Katalogbearb.: Konrad Renger ; Dorothea Schmidt]', 'München', '1982', '167 S.', 'zahlr. Ill.', [{'name': 'Velde, Esaias van den', 'role': 'ill', 'gnd': '(DE-588)120640945'}, {'name': 'Velde, Jan van de', 'role': 'ill', 'gnd': '(DE-588)118767909'}, {'name': 'Rembrandt', 'role': 'ill', 'gnd': '(DE-588)11859964X'}, {'name': 'Ostade, Adriaen van', 'role': 'ill', 'gnd': '(DE-588)118590421'}, {'name': 'Renger, Konrad', 'role': 'edt', 'gnd': '(DE-588)124121195'}, {'name': 'Schmidt, Dorothea', 'role': 'edt'}], [{'word': 'Niederlande', 'type': 'g', 'gnd': '(DE-588)4042203-3'}, {'word': 'Grafik', 'type': 's', 'gnd': '(DE-588)4021845-4'}, {'word': 'Staatliche Graphische Sammlung München', 'type': 'b', 'gnd': '(DE-588)2022332-8'}, {'word': 'Ostade, Adriaen van', 'date': '1610-1685', 'type': 'p', 'gnd': '(DE-588)118590421'}]])
# dict_values(['BV000030886', ['ger'], 'Colloquium Die Stilistische Entwicklung der Italienischen Musik zwischen 1770 und 1830 und ihre Beziehungen zum Norden', '(Rom 1978) ; Bericht', 'hrsg. von Friedrich Lippmann', 'Die stilistische Entwicklung der italienischen Musik zwischen 1770 und 1830 und ihre Beziehungen zum Norden', '[Laaber]', 'Volk, Laaber', '1982', 'VIII, 461 S.', 'Notenbeisp.', [{'name': 'Lippmann, Friedrich', 'role': 'oth', 'gnd': '(DE-588)101387393'}], [{'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}, {'word': 'Musikalischer Stil', 'type': 's', 'gnd': '(DE-588)4170806-4'}], 'BV008002204', 'Analecta musicologica'])
# dict_values(['BV000030980', ['ger'], [{'name': 'May, Georg', 'role': 'Verfasser', 'gnd': '(DE-588)119009358'}], 'Ludwig Kaas', 'der Priester, der Politiker und der Gelehrte aus der Schule von Ulrich Stutz', 'von Georg May', '1', 'Amsterdam', 'Grüner', '(1981)', 'XCV, 707 S.', 'BV000003453', 'Kanonistische Studien und Texte'])
# dict_values(['BV000030982', ['ger'], [{'name': 'May, Georg', 'role': 'Verfasser', 'gnd': '(DE-588)119009358'}], 'Ludwig Kaas', 'der Priester, der Politiker und der Gelehrte aus der Schule von Ulrich Stutz', 'von Georg May', '2', 'Amsterdam', 'Grüner', '(1982)', 'X, 745 S.', 'BV000003453', 'Kanonistische Studien und Texte'])
# dict_values(['BV000030984', ['ger'], [{'name': 'May, Georg', 'role': 'Verfasser', 'gnd': '(DE-588)119009358'}], 'Ludwig Kaas', 'der Priester, der Politiker und der Gelehrte aus der Schule von Ulrich Stutz', 'von Georg May', '3', 'Amsterdam', 'Grüner', '(1982)', 'XII, 613 S.', 'BV000003453', 'Kanonistische Studien und Texte'])
# dict_values(['BV000031355', ['ita'], [{'name': 'Bonifacio, Achille', 'role': 'Verfasser'}], 'Catalogo degli incunabuli della Biblioteca Universitaria di Messina', 'Achille Bonifacio', 'Firenze', 'Olschki', '1982', '169 S.', [{'word': 'Inkunabel', 'type': 's', 'gnd': '(DE-588)4027041-5'}, {'word': 'Università degli studi di Messina Biblioteca', 'type': 'b', 'gnd': '(DE-588)5049311-5'}], 'BV037477166', 'Biblioteca di bibliografia italiana'])
# dict_values(['BV000031484', ['ita'], 'Guida alla città etrusca e al Museo di Marzabotto', 'a cura di Guido A. Mansuelli, Anna Maria Brizzolara, Sandro de Maria, Giuseppe Sassatelli, Daniele Vitali', 'Marzabotto, città errusca e museo', 'Nuova ed.', 'Bologna', 'Edizioni Alfa', '1982', '133 Seiten', 'zahlreiche Illustrationen, Karten', '17 cm', ['1. u. 2. Ausg. u.d.T.: Mansuelli: Guida alla città etrusca e al Museo di Marzabotto'], [{'name': 'Mansuelli, Guido A.', 'role': 'ctb', 'gnd': '(DE-588)120201887'}, {'name': 'Brizzolara, Anna Maria', 'role': 'ctb', 'gnd': '(DE-588)1271625571'}, {'name': 'De Maria, Sandro', 'role': 'ctb', 'gnd': '(DE-588)136607934'}, {'name': 'Sassatelli, Giuseppe', 'role': 'ctb', 'gnd': '(DE-588)14159795X'}, {'name': 'Vitali, Daniele', 'role': 'ctb', 'gnd': '(DE-588)1041726694'}], [{'word': 'Marzabotto', 'type': 'g', 'gnd': '(DE-588)4274955-4'}, {'word': 'Museo Etrusco Pompeo Aria', 'type': 'b', 'gnd': '(DE-588)5126085-2'}, {'word': 'Ausgrabung', 'type': 's', 'gnd': '(DE-588)4129464-6'}], 'BV000003408', 'Guide Jolly'])
# dict_values(['BV000031564', ['ita'], [{'name': 'Vecchi, Maurizia', 'role': 'Verfasser'}], 'Torcello', 'nuove ricerche', 'Roma', "L'Erma di Bretschneider", '1982', 'V, 221 S.', 'Ill. u. Kt.', [{'word': 'Torcello', 'type': 'g', 'gnd': '(DE-588)4078359-5'}, {'word': 'Archäologie', 'type': 's', 'gnd': '(DE-588)4002827-6'}], 'BV000003095', 'Studia archaeologica'])
# dict_values(['BV000031818', ['dut'], 'Verzamelen in Nederland', '[red. deel 32: J. P. Filedt Kok ...]', 'Haarlem', 'Fibula- van Dishoeck', '1982', 'X, 305 S.', 'Ill.', [{'name': 'Filedt Kok, J. P.', 'role': 'edt', 'gnd': '(DE-588)115612610'}], [{'word': 'Niederlande', 'type': 'g', 'gnd': '(DE-588)4042203-3'}, {'word': 'Kunst', 'type': 's', 'gnd': '(DE-588)4114333-4'}], 'BV002664896', 'Nederlands kunsthistorisch jaarboek'])
# dict_values(['BV000032256', ['ger'], 'Die Antike und ihre Wirkung auf die Kunst Europas', 'Württembergischer Verein der Freunde des Humanistischen Gymnasiums. [Mitarb.:] Herwarth Röttgen ...', 'Stuttgart', 'Württemberg. Verein der Freunde des Humanistischen Gymnasiums, Verein für die Pflege Humanistischen Bildungsgutes', '1982', 'VII, 144 S.', 'Ill.', [{'name': 'Röttgen, Herwarth', 'role': 'oth', 'gnd': '(DE-588)122887832'}], [{'word': 'Antike', 'type': 's', 'gnd': '(DE-588)4068754-5'}, {'word': 'Europa', 'type': 'g', 'gnd': '(DE-588)4015701-5'}], 'BV000001495', 'Humanistische Bildung'])
# dict_values(['BV000032691', ['fre'], "La représentation de l'Antiquité au Moyen Age", 'actes du colloque des 26, 27 et 28 mars 1981', "Univ. de Picardie, Centre d'Etudes Médiévales. Publ. par les soins de Danielle Buschinger ...", 'Antiquité au Moyen Age', 'Wien', 'Halosar', '1982', '398 S.', 'Ill.', [{'name': 'Buschinger, Danielle', 'role': 'oth', 'gnd': '(DE-588)119414074'}], [{'word': 'Antike', 'type': 's', 'gnd': '(DE-588)4068754-5'}], 'BV000000998', 'Wiener Arbeiten zur germanischen Altertumskunde und Philologie'])
# dict_values(['BV000033061', ['ger'], [{'name': 'Zurhake, Monika', 'role': 'Verfasser'}], 'Filmische Realitätsaneignung', 'ein Beitrag zur Filmtheorie, mit Analysen von Filmen Vikung Eggelings und Hans Richters', 'Monika Zurhake', 'Heidelberg', 'Winter', '1982', '451 S.', 'Ill., graph. Darst.', [{'word': 'Filmtheorie', 'type': 's', 'gnd': '(DE-588)4071216-3'}, {'word': 'Symphonie Diagonale', 'type': 'u', 'gnd': '(DE-588)4149466-0'}, {'word': 'Richter, Hans', 'date': '1888-1976', 'type': 'p', 'gnd': '(DE-588)118600435'}], 'BV000003488', 'Reihe Siegen'])
# dict_values(['BV000034068', ['ita'], 'Bibliografia topografica della colonizzazione Greca in Italia e nelle isole Tirreniche', 'dir. da G. Nenci ...', '3', 'Pisa [u.a.]', 'Scuola Normale Superiore [u.a.]', '1984', 'XXII, 428 S.', 'zahlr. Kt.', [{'name': 'Nenci, Giuseppe', 'role': 'oth', 'gnd': '(DE-588)119347385'}], []])
# dict_values(['BV000034069', ['ita'], 'Bibliografia topografica della colonizzazione Greca in Italia e nelle isole Tirreniche', 'dir. da G. Nenci ...', '4', 'Pisa [u.a.]', 'Scuola Normale Superiore [u.a.]', '1985', 'XV, 476 S.', 'zahlr. Kt.', [{'name': 'Nenci, Giuseppe', 'role': 'oth', 'gnd': '(DE-588)119347385'}], []])
# dict_values(['BV000034606', ['eng'], [{'name': 'Scribner, Charles', 'role': 'Verfasser'}], 'The triumph of the Eucharist', 'tapestries designed by Rubens', 'by Charles Scribner, III', 'Ann Arbor, Mich.', 'UMI Research Pr.', '1982', 'XV, 224 S.', 'Ill.', [{'word': 'Rubens, Peter Paul', 'date': '1577-1640', 'type': 'u', 'gnd': '(DE-588)4777844-1'}, {'word': 'Rubens, Peter Paul', 'date': '1577-1640', 'type': 'p', 'gnd': '(DE-588)11860354X'}, {'word': 'Bildteppich', 'type': 's', 'gnd': '(DE-588)4006648-4'}, {'word': 'Beneluxländer', 'type': 'g', 'gnd': '(DE-588)4005490-1'}], 'BV000003569', 'Studies in Baroque art history'])
# dict_values(['BV000034779', ['ger'], [{'name': 'Blumenthal, Uta-Renate', 'role': 'Verfasser', 'gnd': '(DE-588)122845749'}], 'Der Investiturstreit', 'Uta-Renate Blumenthal', 'Stuttgart [u.a.]', 'Kohlhammer', '1982', '192 S.', [{'word': 'Investiturstreit', 'type': 's', 'gnd': '(DE-588)4027580-2'}], 'BV040234519', 'Urban-Taschenbücher'])
# dict_values(['BV000034901', ['ger'], 'Ideologie und Herrschaft im Mittelalter', 'hrsg. von Max Kerner', 'Darmstadt', 'Wiss. Buchges.', '1982', 'VIII, 508 S.', [{'name': 'Kerner, Max', 'role': 'oth', 'gnd': '(DE-588)121904075'}], [{'word': 'Herrschaft', 'type': 's', 'gnd': '(DE-588)4024596-2'}], 'BV000000802', 'Wege der Forschung'])
# dict_values(['BV000035613', ['ger'], [{'name': 'Leppmann, Wolfgang', 'role': 'Verfasser', 'gnd': '(DE-588)120406683'}], 'Winckelmann', 'ein Leben für Apoll ; das rätselhafte, dramatische Lebensschicksal des Mannes, der als Vater der Archäologie und Begründer der deutschen Klassik Epoche machte', 'Wolfgang Leppmann', 'Völlig überarb. und erw. Neuausg.', 'Bern ; München', 'Scherz', '1982', '288 S.', 'Ill.', [{'word': 'Winckelmann, Johann Joachim', 'date': '1717-1768', 'type': 'p', 'gnd': '(DE-588)118633600'}]])
# dict_values(['BV000035623', ['ger'], [{'name': 'Maier, Franz Georg', 'role': 'Verfasser', 'gnd': '(DE-588)122386906'}], 'Cypern', 'Insel am Kreuzweg der Geschichte', 'Franz Georg Maier', '2., durchges. und erw. Aufl.', 'München', 'Beck', '1982', '236 S.', 'zahlr. Ill., Kt.', ['Die 1. Aufl. ist 1964 als Bd 81. der Urban-Bücher im Verlag Kohlhammer, Stuttgart, erschienen'], [{'word': 'Zypern', 'type': 'g', 'gnd': '(DE-588)4079596-2'}, {'word': 'Geschichte', 'type': 's', 'gnd': '(DE-588)4020517-4'}]])
# dict_values(['BV000035639', ['eng'], [{'name': 'Read, Benedict', 'role': 'Verfasser'}], 'Victorian sculpture', 'Benedict Read', 'New Haven [u.a.]', 'Yale Univ. Press', '1982', 'X, 414 S.', 'zahlr. Ill.', ['Published for the Paul Mellon Centre for Studies in British Art'], [{'word': 'Großbritannien', 'type': 'g', 'gnd': '(DE-588)4022153-2'}, {'word': 'Plastik', 'type': 's', 'gnd': '(DE-588)4046277-8'}]])
# dict_values(['BV000036165', ['eng'], [{'name': 'Howard, Seymour', 'role': 'Verfasser', 'gnd': '(DE-588)122421841'}], 'Bartolomeo Cavaceppi', 'eighteenth-century restorer', 'Seymour Howard', 'New York [u.a.]', 'Garland', '1982', 'IV, 437 S.', 'zahlr. Ill.', [{'word': 'Cavaceppi, Bartolomeo', 'date': '1716-1799', 'type': 'p', 'gnd': '(DE-588)119217597'}, {'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}, {'word': 'Restaurierung', 'type': 's', 'gnd': '(DE-588)4049600-4'}]])
# dict_values(['BV000036663', ['ger'], 'Literarisches Mäzenatentum', 'ausgewählte Forschungen zur Rolle des Gönners und Auftraggebers in der mittelalterlichen Literatur', 'hrsg. von Joachim Bumke', 'Darmstadt', 'Wiss. Buchges.', '1982', '412 S.', 'Ill.', [{'name': 'Bumke, Joachim', 'role': 'oth', 'gnd': '(DE-588)11571362X'}], [{'word': 'Mäzenatentum', 'type': 's', 'gnd': '(DE-588)4074442-5'}], 'BV000000802', 'Wege der Forschung'])
# dict_values(['BV000036722', ['ger'], [{'name': 'Kern, Hermann', 'role': 'Verfasser', 'gnd': '(DE-588)188417044'}], 'Labyrinthe', 'Erscheinungsformen u. Deutungen ; 5000 Jahre Gegenwart e. Urbilds', 'München', 'Prestel', '1982', '491 S.', 'zahlr. Ill', ['Aus d. Ital. übers.'], [{'word': 'Labyrinth', 'type': 's', 'gnd': '(DE-588)4166337-8'}]])
# dict_values(['BV000037153', ['ger'], [{'name': 'Kurz, Gerhard', 'role': 'Verfasser'}], 'Metapher, Allegorie, Symbol', 'Gerhard Kurz', 'Göttingen', 'Vandenhoeck & Ruprecht', '1982', '103 S.', [{'word': 'Ikonographie', 'type': 's', 'gnd': '(DE-588)4026535-3'}], 'BV000004160', 'Kleine Vandenhoeck-Reihe'])
# dict_values(['BV000037538', ['ger'], [{'name': 'Rehfus-Dechêne, Birgit', 'role': 'Verfasser'}], 'Farbengebung und Farbenlehre in der deutschen Malerei um 1800', 'München', 'Dt. Kunstverl.', '1982', '147 S.', 'graph. Darst.', [{'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Malerei', 'type': 's', 'gnd': '(DE-588)4037220-0'}, {'word': 'Mengs, Anton Raphael', 'date': '1728-1779', 'type': 'p', 'gnd': '(DE-588)118783270'}], 'BV037477561', 'Kunstwissenschaftliche Studien'])
# dict_values(['BV000037645', ['ger'], [{'name': 'Fritz, Johann Michael', 'role': 'Verfasser', 'gnd': '(DE-588)105718076'}], 'Goldschmiedekunst der Gotik in Mitteleuropa', 'Johann Michael Fritz', 'München', 'Verlag C.H. Beck', '1982', '377 Seiten, 401 ungezählte Seiten Bildtafeln, XVI Seiten Bildtafeln', 'Illustrationen', [{'word': 'Mitteleuropa', 'type': 'g', 'gnd': '(DE-588)4039677-0'}, {'word': 'Goldschmiedekunst', 'type': 's', 'gnd': '(DE-588)4113771-1'}]])
# dict_values(['BV000037656', ['ger'], [{'name': 'Marschall, Horst Karl', 'role': 'Verfasser'}], 'Friedrich von Thiersch', 'ein Münchner Architekt des Späthistorismus ; 1852 - 1921', 'Horst Karl Marschall', 'München', 'Prestel', '1982', 'VII, 423 S.', 'zahlr. Ill., Kt.', '25 cm', [{'name': 'Thiersch, Friedrich von', 'role': 'oth', 'gnd': '(DE-588)118622005'}], [{'word': 'Thiersch, Friedrich von', 'date': '1852-1921', 'type': 'p', 'gnd': '(DE-588)118622005'}, {'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Architektur', 'type': 's', 'gnd': '(DE-588)4002851-3'}], 'BV005542358', 'Materialien zur Kunst des 19. Jahrhunderts'])
# dict_values(['BV000037975', ['ger'], 'Das Goldene Evangelienbuch von Echternach', 'eine Prunkhandschrift des 11. Jahrhunderts ; [... erscheint anläßlich der Ausstellung Codex Aureus Epternacensis, das Goldene Evangelienbuch von Echternach, eine mittelalterliche Handschrift und ihr Faksimile, im Theodor-Heuss-Bau des Germanischen Nationalmuseums Nürnberg, vom 10. Juli bis 29. August 1982] = Codex Aureus Epternacensis', 'Germanisches Nationalmuseum Nürnberg, Bibliothek. Von Rainer Kahsnitz ; Ursula Mende ; Elisabeth Rücker', 'Codex aureus Epternacensis', 'Frankfurt am Main', 'Fischer', '1982', '203 S.', 'zahlr. Ill.', ['Literaturverz. S. 198-200'], [{'name': 'Kahsnitz, Rainer', 'role': 'oth', 'gnd': '(DE-588)107493896'}, {'name': 'Mende, Ursula', 'role': 'oth', 'gnd': '(DE-588)1055376372'}, {'name': 'Rücker, Elisabeth', 'role': 'oth', 'gnd': '(DE-588)102716434X'}], [{'word': 'Codex aureus Epternacensis', 'type': 'u', 'gnd': '(DE-588)4148190-2'}, {'word': 'Germanisches Nationalmuseum', 'type': 'b', 'gnd': '(DE-588)36441-1'}, {'word': 'Buchmalerei', 'type': 's', 'gnd': '(DE-588)4008650-1'}, {'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}]])
# dict_values(['BV000037977', ['ita'], "Leonardo all'Ambrosiana", 'il Codice atlantico, i disegni di Leonardo e della sua cerchia', 'a cura di Augusto Marinoni ...', 'Leonardo a Milano, mille quattrocento ottantadue, mille novecento ottantadue', 'Milano', 'Electa', '1982', '163 S.', 'zahlr. Ill.', ['NT: Leonardo a Milano, 1482 [mille quattrocento ottantadue], 1982 [mille novecento ottantadue]'], [{'name': 'Marinoni, Augusto', 'role': 'oth', 'gnd': '(DE-588)122815386'}, {'name': 'Leonardo', 'role': 'oth', 'gnd': '(DE-588)118640445'}], [{'word': 'Leonardo (da Vinci)', 'date': '1452-1519', 'type': 'p', 'gnd': '(DE-588)118640445'}, {'word': 'Zeichnung', 'type': 's', 'gnd': '(DE-588)4127900-1'}, {'word': 'Biblioteca Ambrosiana', 'type': 'b', 'gnd': '(DE-588)4251345-5'}, {'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}], 'BV000001090', 'Fontes ambrosiani'])
# dict_values(['BV000038072', ['ger'], [{'name': 'Benzing, Josef', 'role': 'Verfasser', 'gnd': '(DE-588)118655663'}], 'Die Buchdrucker des 16. und 17. Jahrhunderts im deutschen Sprachgebiet', 'Josef Benzing', 'Die Buchdrucker des sechzehnten und 17. Jahrhunderts im deutschen Sprachgebiet', '2., verb. und erg. Aufl.', 'Wiesbaden', 'Harrassowitz', '1982', 'XX, 565 S.', 'Ill.', ['Erw. Neubearb. ersch. 2007 u.d.T.: Reske, Christoph: Die Buchdrucker des 16. und 17. Jahrhunderts im deutschen Sprachgebiet'], [{'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Buchdruck', 'type': 's', 'gnd': '(DE-588)4008598-3'}], 'BV000005165', 'Beiträge zum Buch- und Bibliothekswesen'])
# dict_values(['BV000038076', ['eng'], 'Fifty years', 'an anniversary catalogue of 120 outstanding books printed before 1700 and sold by H. P. Kraus from 1932 to 1982 ; with a bibliography of all H. P. Kraus rare book catalogues issued during those years', 'New York', 'Kraus', '1982', '264 S.', 'zahlr. Ill.', [{'word': 'H. P. Kraus', 'type': 'b', 'gnd': '(DE-588)32526-0'}, {'word': 'Rara', 'type': 's', 'gnd': '(DE-588)4076518-0'}]])
# dict_values(['BV000038612', ['ger'], 'Theologisches Wörterbuch zum Alten Testament', 'in Verbindung mit George W. Anderson, Henri Cazelles, David N. Freedmann, Shemarjahu Talmon und Gerhard Wallis hrsg. von G. Johannes Botterweck und Helmer Ringgren', '1', 'Stuttgart [u.a.]', 'Kohlhammer', '1973', 'XV S., 1031 Sp., S. 517 - 560', [{'name': 'Botterweck, Gerhard Johannes', 'role': 'oth', 'gnd': '(DE-588)118513990'}, {'name': 'Fabry, Heinz-Josef', 'role': 'oth', 'gnd': '(DE-588)108338827'}, {'name': 'Ringgren, Helmer', 'role': 'oth', 'gnd': '(DE-588)1022640941'}], []])
# dict_values(['BV000038613', ['heb'], 'Theologisches Wörterbuch zum Alten Testament', 'in Verbindung mit George W. Anderson, Henri Cazelles, David N. Freedmann, Shemarjahu Talmon und Gerhard Wallis hrsg. von G. Johannes Botterweck und Helmer Ringgren', '2', 'Stuttgart [u.a.]', 'Kohlhammer', '1977', 'XV S., 1068 Sp., S. 535 - 574', [{'name': 'Botterweck, Gerhard Johannes', 'role': 'oth', 'gnd': '(DE-588)118513990'}, {'name': 'Fabry, Heinz-Josef', 'role': 'oth', 'gnd': '(DE-588)108338827'}, {'name': 'Ringgren, Helmer', 'role': 'oth', 'gnd': '(DE-588)1022640941'}], []])
# dict_values(['BV000038614', ['ger'], 'Theologisches Wörterbuch zum Alten Testament', 'in Verbindung mit George W. Anderson, Henri Cazelles, David N. Freedmann, Shemarjahu Talmon und Gerhard Wallis hrsg. von G. Johannes Botterweck und Helmer Ringgren', '3', 'Stuttgart [u.a.]', 'Kohlhammer', '1982', 'XIII S., 1090 Sp., S. 547 - 568', [{'name': 'Botterweck, Gerhard Johannes', 'role': 'oth', 'gnd': '(DE-588)118513990'}, {'name': 'Fabry, Heinz-Josef', 'role': 'oth', 'gnd': '(DE-588)108338827'}, {'name': 'Ringgren, Helmer', 'role': 'oth', 'gnd': '(DE-588)1022640941'}], []])
# dict_values(['BV000038615', ['ger'], 'Theologisches Wörterbuch zum Alten Testament', 'in Verbindung mit George W. Anderson, Henri Cazelles, David N. Freedmann, Shemarjahu Talmon und Gerhard Wallis hrsg. von G. Johannes Botterweck und Helmer Ringgren', '4', 'Stuttgart [u.a.]', 'Kohlhammer', '1984', 'XV S., 1140 Sp., S. 571 - 595', [{'name': 'Botterweck, Gerhard Johannes', 'role': 'oth', 'gnd': '(DE-588)118513990'}, {'name': 'Fabry, Heinz-Josef', 'role': 'oth', 'gnd': '(DE-588)108338827'}, {'name': 'Ringgren, Helmer', 'role': 'oth', 'gnd': '(DE-588)1022640941'}], []])
# dict_values(['BV000038616', ['ger'], 'Theologisches Wörterbuch zum Alten Testament', 'in Verbindung mit George W. Anderson, Henri Cazelles, David N. Freedmann, Shemarjahu Talmon und Gerhard Wallis hrsg. von G. Johannes Botterweck und Helmer Ringgren', '5', 'Stuttgart [u.a.]', 'Kohlhammer', '1986', 'XIV S., 1208 Sp., S. 605 - 631', [{'name': 'Botterweck, Gerhard Johannes', 'role': 'oth', 'gnd': '(DE-588)118513990'}, {'name': 'Fabry, Heinz-Josef', 'role': 'oth', 'gnd': '(DE-588)108338827'}, {'name': 'Ringgren, Helmer', 'role': 'oth', 'gnd': '(DE-588)1022640941'}], []])
# dict_values(['BV000038850', ['ita'], [{'name': 'Ceratto, Marina', 'role': 'Verfasser'}], 'Il Chi è? delle donne italiane', '1945 - 1982', 'Marina Ceratto', '1. ed.', 'Milano', 'Mondadori', '1982', '339 S.', [{'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}, {'word': 'Frau', 'type': 's', 'gnd': '(DE-588)4018202-2'}]])
# dict_values(['BV000038942', ['ger'], 'Die Zisterzienser', 'Ordensleben zwischen Ideal und Wirklichkeit ; Ausstellung des Landschaftsverbandes Rheinland, Rheinisches Museumsamt, Abtei Brauweiler ; Aachen, 3. Juli - 28. September 1980', 'hrsg. von Kaspar Elm ...', '[2]', 'Köln', 'Rheinland-Verl. [u.a.]', '1982', '270 S.', 'Ill.', [{'name': 'Elm, Kaspar', 'role': 'edt', 'gnd': '(DE-588)119184354'}, {'name': 'Elm, Kaspar', 'role': 'oth', 'gnd': '(DE-588)119184354'}], []])
# dict_values(['BV000038943', ['ger'], 'Kunst des Mittelalters in Armenien', 'Kulturgeschichte, Architektur, Plastik, Wandmalerei, Buchmalerei, angewandte Kunst', 'Burchard Brentjes ... ; Aufn.: K. G. Beyer ...', 'Wien ; München', 'Schroll', '1982', '349 S.', 'zahlr. Ill., Kt.', ['Literaturverz. S. 338 - 342. - Teilw. aus dem Russ. übers.'], [{'name': 'Brentjes, Burchard', 'role': 'oth', 'gnd': '(DE-588)124184723'}, {'name': 'Beyer, Klaus G.', 'role': 'oth', 'gnd': '(DE-588)123811546'}], [{'word': 'Armenien', 'type': 'g', 'gnd': '(DE-588)4085930-7'}, {'word': 'Kunst', 'type': 's', 'gnd': '(DE-588)4114333-4'}]])
# dict_values(['BV000039145', ['ger'], 'Römische Sarkophage', 'von Guntram Koch und Hellmut Sichtermann', 'München', 'Beck', '1982', 'XXIII, 672, [320] S.', 'zahlr. Ill.', ['Regensburg: S. 303 ff.'], [{'name': 'Koch, Guntram', 'role': 'oth', 'gnd': '(DE-588)108353346'}, {'name': 'Sichtermann, Hellmut', 'role': 'oth', 'gnd': '(DE-588)122081846'}], [{'word': 'Römisches Reich', 'type': 'g', 'gnd': '(DE-588)4076778-4'}, {'word': 'Sarkophag', 'type': 's', 'gnd': '(DE-588)4051698-2'}]])
# dict_values(['BV000039147', ['ger'], 'Das Buch im Orient', 'Handschriften und kostbare Drucke aus zwei Jahrtausenden ; Ausstellung 16. November 1982 - 5. Februar 1983', '[Koordination der Ausstellung und Katalogred.: Karl Dachs. Verf. der Katalogbeschr.: Julius Aßfalg ... Ausstellung: Paul Gerhard Dannhauer, Alfons Dufey, Günter Grönbold]', 'Wiesbaden', 'Reichert', '1982', '340 S.', 'Ill.', ['Ausst.: Bayerische Staatsbibliothek <München> : 16.11.1982-5.2.1983'], [{'name': 'Dachs, Karl', 'role': 'oth', 'gnd': '(DE-588)119160722'}, {'name': 'Assfalg, Julius', 'role': 'oth', 'gnd': '(DE-588)11901274X'}, {'name': 'Grönbold, Günter', 'role': 'oth', 'gnd': '(DE-588)107261707'}, {'name': 'Dannhauer, Paul Gerhard', 'role': 'oth', 'gnd': '(DE-588)172052319'}, {'name': 'Dufey, Alfons', 'role': 'oth', 'gnd': '(DE-588)112262309'}], [{'word': 'Bayerische Staatsbibliothek', 'type': 'b', 'gnd': '(DE-588)2031351-2'}, {'word': 'Ferner Osten', 'type': 'g', 'gnd': '(DE-588)4016795-1'}, {'word': 'Handschrift', 'type': 's', 'gnd': '(DE-588)4023287-6'}]])
# dict_values(['BV000039198', ['ger'], [{'name': 'Asche, Kurt', 'role': 'Verfasser', 'gnd': '(DE-588)119149559'}], 'Das Bürgerhaus in Oldenburg', 'von Kurt Asche', 'Tübingen', 'Wasmuth', '1982', '237, 108 S.', 'zahlr. Ill., Kt.', [{'word': 'Oldenburg (Oldenburg)', 'type': 'g', 'gnd': '(DE-588)4043457-6'}, {'word': 'Bürgerhaus', 'type': 's', 'gnd': '(DE-588)4008773-6'}], 'BV000002026', 'Das deutsche Bürgerhaus'])
# dict_values(['BV000039200', ['eng'], [{'name': 'Miller, Naomi', 'role': 'Verfasser'}], 'Heavenly caves', 'reflections on the garden grotto', 'Naomi Miller', '1. ed.', 'New York', 'Braziller', '1982', '141 S.', 'zahlr. Ill.', [{'word': 'Grotte', 'type': 's', 'gnd': '(DE-588)4158326-7'}]])
# dict_values(['BV000039201', ['eng', 'ita'], 'Avanguardia, Transavanguardia', '[Mura Aureliane da Porta Metronia a Porta Latina, aprile - luglio 1982]', 'a cura di Achille Bonito Oliva', 'Milano', 'Electa', '1982', '143 S.', 'überwiegend Ill.', [{'name': 'Bonito Oliva, Achille', 'role': 'oth', 'gnd': '(DE-588)121152332'}], [{'word': 'Avantgarde', 'type': 's', 'gnd': '(DE-588)4133965-4'}]])
# dict_values(['BV000039397', ['ger'], 'Lexikon der Informatik und Datenverarbeitung', 'hrsg. von Hans-Jochen Schneider', 'München u.a.', 'Oldenbourg', '1983', 'XII, 667 S.', 'graph. Darst.', ['4. Aufl. u. d. T.: Lexikon Informatik und Datenverarbeitung'], [{'name': 'Schneider, Hans-Jochen', 'role': 'oth'}], [{'word': 'Informatik', 'type': 's', 'gnd': '(DE-588)4026894-9'}]])
# dict_values(['BV000039468', ['eng'], [{'name': 'Bell, Robert E.', 'role': 'Verfasser'}], 'Dictionary of classical mythology', 'symbols, attributes and associations', 'Oxford u.a.', 'ABC Clio', '1982', 'XI, 390 S.', 'Ill.', [{'word': 'Antike', 'type': 's', 'gnd': '(DE-588)4068754-5'}]])
# dict_values(['BV000039527', ['ger'], [{'name': 'Clutton, Cecil', 'role': 'Verfasser'}], 'Taschenuhren', 'Geschichte und Technik', 'Cecil Clutton ; George Daniels', 'München', 'Beck', '1982', '336 S.', 'zahlr. Ill.', ['EST: Watches <dt.>. - Aus d. Engl. übers.'], [{'name': 'Daniels, George', 'role': 'aut'}], [{'word': 'Taschenuhr', 'type': 's', 'gnd': '(DE-588)4059095-1'}], 'Watches'])
# dict_values(['BV000039551', ['ger'], 'Die Glassammlung des Bayerischen Nationalmuseums München', 'bearb. von Rainer Rückert', '1', 'München', 'Hirmer', '(1982)', '176, 131 S.', 'zahlr. Ill.', [{'name': 'Rückert, Rainer', 'role': 'oth'}], 'BV038751918', 'Kataloge des Bayerischen Nationalmuseums'])
# dict_values(['BV000039553', ['ger'], 'Die Glassammlung des Bayerischen Nationalmuseums München', 'bearb. von Rainer Rückert', '2', 'München', 'Hirmer', '(1982)', 'S. 179 - 372, 133 - 330', 'zahlr. Ill.', [{'name': 'Rückert, Rainer', 'role': 'oth'}], 'BV038751918', 'Kataloge des Bayerischen Nationalmuseums'])
# dict_values(['BV000039787', ['ger'], [{'name': 'Förschner, Gisela', 'role': 'Verfasser', 'gnd': '(DE-588)123672422'}], 'Glaspasten, geschnittene Steine, arabische Münzgewichte', 'Sammlungen des Münzkabinetts aus dem bürgerlichen Bildungsgut des 19. Jahrhunderts in Frankfurt am Main', 'Gisela Förschner', 'Melsungen', 'Verlag Gutenberg', '1982', '111 Seiten', 'Illustrationen', [{'word': 'Historisches Museum Frankfurt Münzsammlung', 'type': 'b', 'gnd': '(DE-588)2034705-4'}, {'word': 'Gemme', 'type': 's', 'gnd': '(DE-588)4020059-0'}, {'word': 'Arabien', 'type': 'g', 'gnd': '(DE-588)4002529-9'}], 'BV000895553', 'Kleine Schriften des Historischen Museums'])
# dict_values(['BV000040260', ['ger'], [{'name': 'Huth, Hans', 'role': 'Verfasser', 'gnd': '(DE-588)1052643485'}], 'Die Kunstdenkmäler des Stadtkreises Mannheim', 'bearb. von Hans Huth', '1', 'München', 'Dt. Kunstverl.', '1982', 'XVIII, 855 S.', 'zahlr. Ill., Kt.'])
# dict_values(['BV000040261', ['ger'], [{'name': 'Huth, Hans', 'role': 'Verfasser', 'gnd': '(DE-588)1052643485'}], 'Die Kunstdenkmäler des Stadtkreises Mannheim', 'bearb. von Hans Huth', '2', 'München', 'Dt. Kunstverl.', '1982', 'S. 856 - 1815', 'zahlr. Ill., Kt.'])
# dict_values(['BV000040372', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil I, 1. Band', 'Tutzing', 'Schneider', '1975', 'XXXV, 418 S.'])
# dict_values(['BV000040373', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil I, 2. Band', 'Tutzing', 'Schneider', '1975', 'S. 419 - 882'])
# dict_values(['BV000040374', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil I, 3. Band', 'Tutzing', 'Schneider', '1975', 'S. 883 - 1344'])
# dict_values(['BV000040375', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil II, 1. Band', 'Tutzing', 'Schneider', '1977', 'XII, 371 S.'])
# dict_values(['BV000040376', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil 2, 2. Band', 'Tutzing', 'Schneider', '1977', 'S. 373 - 772'])
# dict_values(['BV000040377', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil II, 3. Band', 'Tutzing', 'Schneider', '1978', 'S. 773 - 1194'])
# dict_values(['BV000040378', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil III, 1. Band', 'Tutzing', 'Schneider', '1979', '328 S.'])
# dict_values(['BV000040379', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil III, 2. Band', 'Tutzing', 'Schneider', '1980', 'S. 333 - 775'])
# dict_values(['BV000040380', ['ger', 'eng', 'fre', 'ita'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil III, 3. Band', 'Tutzing', 'Schneider', '1981', 'S. 781 - 1043'])
# dict_values(['BV000040381', ['ger'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil IV, 1. Band', 'Tutzing', 'Schneider', '1982', '328 S.'])
# dict_values(['BV000040382', ['ger'], [{'name': 'Stieger, Franz', 'role': 'Verfasser', 'gnd': '(DE-588)113173865'}], 'Opernlexikon', 'Franz Stieger', 'Teil IV, 2. Band', 'Tutzing', 'Schneider', '1983', '530 S.'])
# dict_values(['BV000040383', ['fre'], [{'name': 'Tillet, Louise-Marie', 'role': 'Verfasser'}], 'Bretagne romane', '[Paris]', 'Zodiaque', '1982', '345 S.', 'zahlr. Ill. u. Kt.', [{'word': 'Bretagne', 'type': 'g', 'gnd': '(DE-588)4008220-9'}, {'word': 'Architektur', 'type': 's', 'gnd': '(DE-588)4002851-3'}], 'BV000000883', 'La nuit des temps'])
# dict_values(['BV000040459', ['eng'], 'Catalogue of paintings', 'Cleveland Museum of Art', '1', 'Cleveland, Ohio', '1974', 'XVI, 183 S.', 'zahlr. Ill.'])
# dict_values(['BV000040460', ['eng'], 'Catalogue of paintings', 'Cleveland Museum of Art', '3', 'Cleveland, Ohio', '1982', 'XVI, 542 S.', 'zahlr. Ill.'])
# dict_values(['BV000040710', ['ger'], [{'name': 'Kühlmann, Wilhelm'}], 'Gelehrtenrepublik und Fürstenstaat', 'Entwicklung und Kritik des deutschen Späthumanismus in der Literatur des Barockzeitalters', 'Wilhelm Kühlmann', 'Tübingen', 'Niemeyer', '1982', 'X, 533 Seiten', [{'word': 'Deutschland', 'type': 'g', 'gnd': '(DE-588)4011882-4'}, {'word': 'Humanismus', 'type': 's', 'gnd': '(DE-588)4026140-2'}], 'BV000001835', 'Studien und Texte zur Sozialgeschichte der Literatur'])
# dict_values(['BV000040927', ['ita'], "Francesco d'Assisi", '[mostre di Assisi, Foligno, Narni, Perugia e Todi ...]', '[dir. ed.: Carlo Pirovano] ...', '[1]', 'Milano', 'Electa', '1982', '393 S.', 'zahlr. Ill., Notenbeisp.', [{'name': 'Pirovano, Carlo', 'role': 'oth', 'gnd': '(DE-588)1057041556'}, {'name': 'Porzio, Francesco', 'role': 'oth', 'gnd': '(DE-588)136023681'}, {'name': 'Selvafolta, Ornella', 'role': 'oth', 'gnd': '(DE-588)141377240'}], []])
# dict_values(['BV000040928', ['ita'], "Francesco d'Assisi", '[mostre di Assisi, Foligno, Narni, Perugia e Todi ...]', '[dir. ed.: Carlo Pirovano] ...', '[2]', 'Milano', 'Electa', '1982', '197 S.', 'zahlr. Ill., Notenbeisp.', [{'name': 'Pirovano, Carlo', 'role': 'oth', 'gnd': '(DE-588)1057041556'}, {'name': 'Porzio, Francesco', 'role': 'oth', 'gnd': '(DE-588)136023681'}, {'name': 'Selvafolta, Ornella', 'role': 'oth', 'gnd': '(DE-588)141377240'}], []])
# dict_values(['BV000040929', ['ita'], "Francesco d'Assisi", '[mostre di Assisi, Foligno, Narni, Perugia e Todi ...]', '[dir. ed.: Carlo Pirovano] ...', '[3]', 'Milano', 'Electa', '1982', '185 S.', 'zahlr. Ill., graph. Darst., Kt.', [{'name': 'Pirovano, Carlo', 'role': 'oth', 'gnd': '(DE-588)1057041556'}, {'name': 'Porzio, Francesco', 'role': 'oth', 'gnd': '(DE-588)136023681'}, {'name': 'Selvafolta, Ornella', 'role': 'oth', 'gnd': '(DE-588)141377240'}], []])
# dict_values(['BV000040935', ['lat'], [{'name': 'Nikolaus', 'role': 'Verfasser', 'gnd': '(DE-588)118588095'}], 'Nicolai de Cusa opera omnia', 'iussu et auctoritate Academiae Litterarum Heidelbergensis ad codicum fidem edita', 'ed. ... Ludovicus Hagemann', '8', 'Lipsiae [u.a.]', 'Meiner', '1986', 'XXXIX, 370 S.', [{'name': 'Hagemann, Ludwig', 'role': 'oth', 'gnd': '(DE-588)120270773'}], [], 'Cribratio alkorani'])
# dict_values(['BV000040936', ['lat'], [{'name': 'Nikolaus', 'role': 'Verfasser', 'gnd': '(DE-588)118588095'}], 'Nicolai de Cusa opera omnia', 'iussu et auctoritate Academiae Litterarum Heidelbergensis ad codicum fidem edita', 'ed. comm. illustr. Raymundus Klibansky ...', '12', 'Lipsiae [u.a.]', 'Meiner', '1982', 'XXX, 249 S.', 'Opera omnia'])
# dict_values(['BV000041047', ['ger'], [{'name': 'Goethe, Johann Wolfgang von', 'role': 'Verfasser', 'gnd': '(DE-588)118540238'}], 'Johann Wolfgang Goethe zu Bildern', 'hrsg. von Christoph Michel ...', '1. Aufl.', 'Frankfurt am Main', 'Insel-Verl.', '1982', '358 S.', 'zahlr. Ill.', [{'name': 'Michel, Christoph', 'role': 'oth', 'gnd': '(DE-588)120380803'}], [], 'BV008238049', 'Insel-Verlag Anton Kippenberg <Frankfurt, Main>: Insel-Almanach auf das Jahr ...'])
# dict_values(['BV000042173', ['ger'], [{'name': 'Lietz, Sabine', 'role': 'Verfasser'}], 'Das Fenster des Barock', 'Fenster und Fensterzubehör in der fürstlichen Profanarchitektur zwischen 1680 und 1780', 'Sabine Lietz', 'München', 'Dt. Kunstverl.', '1982', '185 S.', 'zahlr. Ill.', [{'word': 'Fenster', 'type': 's', 'gnd': '(DE-588)4016740-9'}, {'word': 'Mitteleuropa', 'type': 'g', 'gnd': '(DE-588)4039677-0'}], 'BV037477561', 'Kunstwissenschaftliche Studien'])
# dict_values(['BV000042225', ['ita'], [{'name': 'Colonna, Vittoria', 'role': 'Verfasser', 'gnd': '(DE-588)118669818'}], 'Rime', 'Vottoria Colonna. A cura di Alan Bullock', 'Roma [u.a.]', 'Laterza', '1982', '526 S.', [{'name': 'Bullock, Alan', 'role': 'oth', 'gnd': '(DE-588)128746122'}], [{'word': 'Sandoval de Castro, Diego', 'date': '-1546', 'type': 'p', 'gnd': '(DE-588)143241184'}, {'word': 'Lyrik', 'type': 's', 'gnd': '(DE-588)4036774-5'}], 'BV000000736', "Scrittori d'Italia"])
# dict_values(['BV000042546', ['ger'], [{'name': 'Buchner, Edmund', 'role': 'Verfasser', 'gnd': '(DE-588)104989262'}], 'Die Sonnenuhr des Augustus', 'Nachdruck aus RM 1976 und 1980 und Nachtrag über die Ausgrabung 1980/1981', 'Edmund Buchner', 'Mainz am Rhein', '<<von>> Zabern', '1982', '112 S.', 'zahlr. Ill., graph. Darst., Kt.', [{'word': 'Rom', 'type': 'g', 'gnd': '(DE-588)4224567-9'}, {'word': 'Augustus (Römisches Reich, Kaiser)', 'date': 'v63-14', 'type': 'p', 'gnd': '(DE-588)118505122'}, {'word': 'Sonnenuhr', 'type': 's', 'gnd': '(DE-588)4055589-6'}]])
# dict_values(['BV000042901', ['ger'], [{'name': 'Renger-Patzsch, Albert', 'role': 'Verfasser', 'gnd': '(DE-588)118599690'}], 'Ruhrgebiet-Landschaften 1927 - 1935', 'Albert Renger-Patzsch. Ann u. Jürgen Wilde. Mit einem Text von Dieter Thoma Im Ruhrgebiet', 'Albert Renger-Patzsch: Ruhrgebiet-Landschaften 1927 - 1935', 'Köln', 'DuMont', '1982', '176 S.', 'überw. Ill.', [{'name': 'Wilde, Ann', 'role': 'oth', 'gnd': '(DE-588)119285789'}, {'name': 'Wilde, Jürgen', 'role': 'edt', 'gnd': '(DE-588)119288877'}], [{'word': 'Renger-Patzsch, Albert', 'date': '1897-1966', 'type': 'p', 'gnd': '(DE-588)118599690'}, {'word': 'Ruhrgebiet', 'type': 'g', 'gnd': '(DE-588)4050926-6'}, {'word': 'Landschaftsfotografie', 'type': 's', 'gnd': '(DE-588)4132170-4'}]])
# dict_values(['BV000043014', ['fre'], [{'name': 'Barsabas', 'role': 'Verfasser', 'gnd': '(DE-588)102386854'}], 'Sur le Christ et les églises', 'Barsabée de Jérusalem. Introd., éd. du texte géorgien inéd. et trad. française par Michel van Esbroeck', 'Turnhout, Belgique', 'Brepols', '1982', 'S. 152 - 255', [{'name': 'Van Esbroeck, Michel', 'role': 'edt', 'gnd': '(DE-588)107959712'}], [{'word': 'Theologie', 'type': 's', 'gnd': '(DE-588)4059758-1'}], 'BV035929039', 'Patrologia orientalis'])
# dict_values(['BV000043346', ['ger'], 'Jenseitsvorstellungen in Antike und Christentum', 'Gedenkschrift für Alfred Stuiber', '... im Auftr. ... hrsg. von Theodor Klauser ...', 'Münster, Westfalen', 'Aschendorff', '1982', 'XX, 250 S.', 'Ill.', ['Festschrift Alfred Stuiber'], [{'name': 'Stuiber, Alfred', 'role': 'hnr', 'gnd': '(DE-588)118799266'}, {'name': 'Klauser, Theodor', 'role': 'edt', 'gnd': '(DE-588)118723391'}], [{'word': 'Jenseitsglaube', 'type': 's', 'gnd': '(DE-588)4162734-9'}, {'word': 'Stuiber, Alfred', 'date': '1912-1981', 'type': 'p', 'gnd': '(DE-588)118799266'}]])
# dict_values(['BV000043416', ['eng'], 'Crusader art in the twelfth century', 'The British School of Archaeology in Jerusalem. Ed. by Jaroslav Folda', 'Oxford', 'B.A.R.', '1982', 'XII, 269 S.', 'Ill., Kt.', [{'name': 'Folda, Jaroslav', 'role': 'oth'}], [{'word': 'Kreuzfahrer', 'type': 's', 'gnd': '(DE-588)4165646-5'}], 'BV023549802', 'British archaeological reports'])
# dict_values(['BV000043480', ['ger'], 'Forschungen zur Villa Albani', 'antike Kunst und die Epoche der Aufklärung', 'hrsg. von Herbert Beck und Peter C. Bol', 'Berlin', 'Mann', '1982', 'XV, 562, 178 S.', 'zahlr. Ill.', [{'name': 'Beck, Herbert', 'role': 'oth', 'gnd': '(DE-588)123051231'}, {'name': 'Bol, Peter C.', 'role': 'edt', 'gnd': '(DE-588)133105229'}], [{'word': 'Villa Albani', 'type': 'g', 'gnd': '(DE-588)4197499-2'}, {'word': 'Architektur', 'type': 's', 'gnd': '(DE-588)4002851-3'}], 'BV000002080', 'Frankfurter Forschungen zur Kunst'])
# dict_values(['BV000043652', ['eng'], [{'name': 'Rhodes, Dennis E.', 'role': 'Verfasser', 'gnd': '(DE-588)11913263X'}], 'A catalogue of incunabula in all the libraries of Oxford University outside the Bodleian', 'Dennis E. Rhodes', 'Oxford', 'Clarendon Pr.', '1982', 'XLI, 444 S.', [{'word': 'University of Oxford', 'type': 'b', 'gnd': '(DE-588)36214-1'}, {'word': 'Bibliothek', 'type': 's', 'gnd': '(DE-588)4006439-6'}, {'word': 'Oxford', 'type': 'g', 'gnd': '(DE-588)4044234-2'}]])
# dict_values(['BV000044082', ['ger'], 'Köpfe der Lutherzeit', '[Hamburger Kunsthalle, 4. März - 24. April 1983', 'hrsg. von Werner Hofmann. [Katalog: Eckhard Schaar u. Gisela Hopp. Beitr. von: Werner Hofmann u. Peter-Klaus Schuster]', 'München', 'Prestel', '1983', '318 S.', 'zahlr. Ill.', '8', ['Literaturverz. S. 311 - 314'], [{'name': 'Hofmann, Werner', 'role': 'oth', 'gnd': '(DE-588)120644398'}, {'name': 'Schaar, Eckhard', 'role': 'oth', 'gnd': '(DE-588)134093836'}, {'name': 'Hopp, Gisela', 'role': 'oth'}], [{'word': 'Ferdinand I. (Heiliges Römisches Reich, Kaiser)', 'date': '1503-1564', 'type': 'p', 'gnd': '(DE-588)118532502'}, {'word': 'Bildnis', 'type': 's', 'gnd': '(DE-588)4006627-7'}]])
# dict_values(['BV000044094', ['ger'], 'Geschichte als Paradigma', 'zur Reflexion des Historischen in der Kunst', 'hrsg. von Gerhard Charles Rump', 'Bonn', 'Habelt', '1982', '121 S.', 'Ill.', [{'name': 'Rump, Gerhard Charles', 'role': 'oth', 'gnd': '(DE-588)108564738'}], [{'word': 'Geschichtsphilosophie', 'type': 's', 'gnd': '(DE-588)4020529-0'}], 'BV000005398', 'Kunstwissenschaftliche Thesenhefte'])
# ...
# dict_values(['BV001239441', ['ger'], 'Die Kunstdenkmäler des Kantons Aargau', 'von Emil Maurer', '3', 'Basel', 'Birkhäuser', '1954', 'VII, 359 S.', 'zahlr. Ill., Kt.', [{'name': 'Maurer, Emil', 'role': 'oth', 'gnd': '(DE-588)122759249'}, {'name': 'Stettler, Michael', 'role': 'oth', 'gnd': '(DE-588)119527405'}, {'name': 'Hoegger, Peter', 'role': 'oth', 'gnd': '(DE-588)1017534322'}, {'name': 'Maurer, Emil', 'role': 'oth', 'gnd': '(DE-588)122759249'}], [{'word': 'Kloster Königsfelden', 'type': 'b', 'gnd': '(DE-588)4207593-2'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239443', ['ger'], 'Die Kunstdenkmäler des Kantons Aargau', 'von Peter Felder', '4', 'Basel', 'Birkhäuser', '1967', 'XII, 491 S.', 'zahlr. Ill., Kt.', [{'name': 'Felder, Peter', 'role': 'oth', 'gnd': '(DE-588)105037141'}, {'name': 'Stettler, Michael', 'role': 'oth', 'gnd': '(DE-588)119527405'}, {'name': 'Hoegger, Peter', 'role': 'oth', 'gnd': '(DE-588)1017534322'}, {'name': 'Maurer, Emil', 'role': 'oth', 'gnd': '(DE-588)122759249'}], [{'word': 'Bezirk Bremgarten', 'type': 'g', 'gnd': '(DE-588)4549847-7'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239445', ['ger'], 'Die Kunstdenkmäler des Kantons Aargau', 'von Georg Germann', '5', 'Basel', 'Birkhäuser', '1967', 'XII, 576 S.', 'zahlr. Ill., Kt.', [{'name': 'Germann, Georg', 'role': 'oth', 'gnd': '(DE-588)136286682'}, {'name': 'Stettler, Michael', 'role': 'oth', 'gnd': '(DE-588)119527405'}, {'name': 'Hoegger, Peter', 'role': 'oth', 'gnd': '(DE-588)1017534322'}, {'name': 'Maurer, Emil', 'role': 'oth', 'gnd': '(DE-588)122759249'}], [{'word': 'Bezirk Muri', 'type': 'g', 'gnd': '(DE-588)4409142-4'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239447', ['ger'], 'Die Kunstdenkmäler des Kantons Aargau', 'von Peter Hoegger', '6', 'Basel', 'Birkhäuser', '1976', 'XII, 511 S.', 'zahlr. Ill., Kt.', [{'name': 'Hoegger, Peter', 'role': 'oth', 'gnd': '(DE-588)1017534322'}, {'name': 'Stettler, Michael', 'role': 'oth', 'gnd': '(DE-588)119527405'}, {'name': 'Hoegger, Peter', 'role': 'oth', 'gnd': '(DE-588)1017534322'}, {'name': 'Maurer, Emil', 'role': 'oth', 'gnd': '(DE-588)122759249'}], [{'word': 'Bezirk Baden', 'type': 'g', 'gnd': '(DE-588)4004165-7'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239451', ['ger'], 'Die Kunstdenkmäler des Kantons Thurgau', 'von Albert Knoepfli', '1', 'Basel', 'Birkhäuser', '1950', 'XIV, 480 S.', 'Ill., Kt.', [{'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Raimann, Alfons', 'role': 'oth', 'gnd': '(DE-588)139727213'}, {'name': 'Erni, Peter', 'role': 'oth', 'gnd': '(DE-588)139727434'}], [{'word': 'Bezirk Frauenfeld', 'type': 'g', 'gnd': '(DE-588)4093213-8'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239453', ['ger'], 'Die Kunstdenkmäler des Kantons Thurgau', 'von Albert Knoepfli', '2', 'Basel', 'Birkhäuser', '1955', 'VIII, 432 S.', 'zahlr. Ill., Kt.', [{'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Raimann, Alfons', 'role': 'oth', 'gnd': '(DE-588)139727213'}, {'name': 'Erni, Peter', 'role': 'oth', 'gnd': '(DE-588)139727434'}], [{'word': 'Bezirk Münchwilen', 'type': 'g', 'gnd': '(DE-588)4101721-3'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239455', ['ger'], 'Die Kunstdenkmäler des Kantons Thurgau', 'von Albert Knoepfli', '3', 'Basel', 'Birkhäuser', '1962', 'XII, 584 S.', 'zahlr. Ill., Kt.', [{'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Knoepfli, Albert', 'role': 'oth', 'gnd': '(DE-588)118723804'}, {'name': 'Raimann, Alfons', 'role': 'oth', 'gnd': '(DE-588)139727213'}, {'name': 'Erni, Peter', 'role': 'oth', 'gnd': '(DE-588)139727434'}], [{'word': 'Bezirk Bischofszell', 'type': 'g', 'gnd': '(DE-588)4781906-6'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239457', ['ger'], [{'name': 'Poeschel, Erwin', 'role': 'Verfasser', 'gnd': '(DE-588)107543176'}], 'Die Kunstdenkmäler des Fürstentums Liechtenstein', 'von Erwin Poeschel', 'Basel', 'Birkhäuser', '1950', 'VIII, 308 S.', 'Ill., Kt.', [{'word': 'Liechtenstein', 'type': 'g', 'gnd': '(DE-588)4035665-6'}, {'word': 'Kunst', 'type': 's', 'gnd': '(DE-588)4114333-4'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239467', ['ger'], 'Die Kunstdenkmäler des Kantons Solothurn', 'von Gottlieb Loertscher', '3', 'Basel', 'Wiese', '1957', 'XII, 456 S.', 'zahlr. Ill., Kt.', [{'name': 'Loertscher, Gottlieb', 'role': 'oth', 'gnd': '(DE-588)1055479961'}, {'name': 'Schubiger, Benno', 'role': 'oth'}, {'name': 'Blank, Stefan', 'role': 'oth', 'gnd': '(DE-588)124171818'}, {'name': 'Hochstrasser, Markus', 'role': 'oth', 'gnd': '(DE-588)1028326343'}], [{'word': 'Bezirk Thal', 'type': 'g', 'gnd': '(DE-588)4117198-6'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239477', ['ger'], 'Die Kunstdenkmäler des Kantons Appenzell Ausserrhoden', 'von Eugen Steinmann', '1', 'Basel', 'Birkhäuser', '1973', 'XV, 468 S.', 'zahlr. Ill., Kt.', [{'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}, {'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}], [{'word': 'Bezirk Hinterland', 'type': 'g', 'gnd': '(DE-588)4024973-6'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239479', ['ger'], 'Die Kunstdenkmäler des Kantons Appenzell Ausserrhoden', 'von Eugen Steinmann', '2', 'Basel', 'Birkhäuser', '1980', 'XVI, 463 S.', 'Ill., Kt.', [{'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}, {'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}], [{'word': 'Bezirk Mittelland', 'type': 'g', 'gnd': '(DE-588)4202768-8'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239481', ['ger'], 'Die Kunstdenkmäler des Kantons Appenzell Ausserrhoden', 'von Eugen Steinmann', '3', 'Basel', 'Birkhäuser', '1981', 'XVI, 446 S.', 'Ill., Kt.', [{'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}, {'name': 'Steinmann, Eugen', 'role': 'oth', 'gnd': '(DE-588)142816329'}], [{'word': 'Vorderland', 'type': 'g', 'gnd': '(DE-588)4063959-9'}, {'word': 'Kunst', 'type': 's', 'gnd': '(DE-588)4114333-4'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239484', ['ger'], 'Die Kunstdenkmäler des Kantons Wallis', 'von Walter Ruppen', '1', 'Basel', 'Birkhäuser', '1976', 'XVI, 464 S.', 'Ill., Kt.', [{'name': 'Ruppen, Walter', 'role': 'oth'}, {'name': 'Ackermann-Kuonen, Carmela', 'role': 'oth'}, {'name': 'Elsig, Patrick', 'role': 'oth'}], [{'word': 'Obergoms', 'type': 'g', 'gnd': '(DE-588)4738657-5'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239486', ['ger'], 'Die Kunstdenkmäler des Kantons Wallis', 'von Walter Ruppen', '2', 'Basel', 'Birkhäuser', '1979', 'XVI, 478 S.', 'zahlr. Ill., Kt.', [{'name': 'Ruppen, Walter', 'role': 'oth'}, {'name': 'Ackermann-Kuonen, Carmela', 'role': 'oth'}, {'name': 'Elsig, Patrick', 'role': 'oth'}], [{'word': 'Untergoms', 'type': 'g', 'gnd': '(DE-588)4107442-7'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239489', ['ger'], 'Die Kunstdenkmäler des Kantons Schwyz', 'von André Meyer', '1', 'Basel', 'Wiese', '1978', 'XV, 545 S.', 'zahlr. Ill., Kt.', [{'name': 'Meyer, André', 'role': 'oth'}, {'name': 'Meyer, André', 'role': 'oth', 'gnd': '(DE-588)1105481433'}, {'name': 'Jörger, Albert', 'role': 'oth', 'gnd': '(DE-588)1126660280'}], [{'word': 'Bezirk Schwyz', 'type': 'g', 'gnd': '(DE-588)4054018-2'}, {'word': 'Baudenkmal', 'type': 's', 'gnd': '(DE-588)4004973-5'}], 'BV040152217', 'Die Kunstdenkmäler der Schweiz'])
# dict_values(['BV001239497', ['ger'], [{'name': 'Pächt, Otto', 'role': 'Verfasser', 'gnd': '(DE-588)119251213'}], 'Flämische Schule', 'Otto Pächt ; Ulrike Jenni ; Dagmar Thoss', '1,[1]', 'Wien', 'Verl. der Österreichischen Akad. der Wiss.', '1983', '213 S., [29] Bl.', 'Ill.', [{'name': 'Jenni, Ulrike', 'role': 'aut', 'gnd': '(DE-588)111124158'}, {'name': 'Thoss, Dagmar', 'role': 'aut', 'gnd': '(DE-588)130496421'}], [{'word': 'Österreichische Nationalbibliothek', 'type': 'b', 'gnd': '(DE-588)2020893-5'}, {'word': 'Illuminierte Handschrift', 'type': 's', 'gnd': '(DE-588)4120472-4'}, {'word': 'Flandern', 'type': 'g', 'gnd': '(DE-588)4071249-7'}], 'BV024768009', 'Veröffentlichungen der Kommission für Schrift- und Buchwesen des Mittelalters'])
# dict_values(['BV001239500', ['ger'], [{'name': 'Pächt, Otto', 'role': 'Verfasser', 'gnd': '(DE-588)119251213'}], 'Flämische Schule', 'Otto Pächt ; Ulrike Jenni ; Dagmar Thoss', '1,[2]', 'Wien', 'Verl. der Österreichischen Akad. der Wiss.', '1983', '13 S., [77] Bl.', 'überw. Ill.', [{'name': 'Jenni, Ulrike', 'role': 'aut', 'gnd': '(DE-588)111124158'}, {'name': 'Thoss, Dagmar', 'role': 'aut', 'gnd': '(DE-588)130496421'}], [{'word': 'Österreichische Nationalbibliothek', 'type': 'b', 'gnd': '(DE-588)2020893-5'}, {'word': 'Flandern', 'type': 'g', 'gnd': '(DE-588)4071249-7'}, {'word': 'Illuminierte Handschrift', 'type': 's', 'gnd': '(DE-588)4120472-4'}], 'BV024768009', 'Veröffentlichungen der Kommission für Schrift- und Buchwesen des Mittelalters'])
# dict_values(['BV001240078', ['ger'], [{'name': 'Hell, Vera', 'role': 'Verfasser', 'gnd': '(DE-588)1026075866'}], 'Türkei', 'Kunst- und Reiseführer mit Landeskunde', 'Vera und Hellmut Hell', '2', '2., neu bearb. u. erw. Aufl.', 'Stuttgart [u.a.]', 'Kohlhammer', '1985', '281 S.', 'Ill., Kt.', [{'name': 'Hell, Hellmut', 'role': 'aut', 'gnd': '(DE-588)174219512'}], []])
# dict_values(['BV001240308', ['eng'], [{'name': 'Wallace-Hadrill, Andrew', 'role': 'Verfasser', 'gnd': '(DE-588)136807798'}], 'Suetonius', 'the scholar and his Caesars', 'Andrew Wallace-Hadrill', 'London', 'Duckworth', '1983', 'VIII, 216 S.', [{'word': 'Suetonius Tranquillus, Gaius', 'date': '70-150', 'type': 'p', 'gnd': '(DE-588)118619918'}]])
# dict_values(['BV001240638', ['ger'], [{'name': 'Jauß, Hans Robert', 'role': 'Verfasser', 'gnd': '(DE-588)118557149'}], 'Ästhetische Erfahrung und literarische Hermeneutik', 'Hans Robert Jauß', '2. Aufl.', 'Frankfurt am Main', 'Suhrkamp', '1984', '876 S.', ['Literaturverz. S. 868 - 874'], [{'word': 'Hermeneutik', 'type': 's', 'gnd': '(DE-588)4128972-9'}]])
# dict_values(['BV001241554', ['fre', 'syc', 'lat'], [{'name': 'Athanasius', 'role': 'Verfasser', 'gnd': '(DE-588)118504843'}], "Histoire Acéphale et index syriaque des lettres festales d'Athanase d'Alexandrie", 'introd., texte critique, trad. et notes par Annik Martin ...', 'Paris', 'Éd. du Cerf', '1985', '377 S.', 'Kt.', ['Text teilw. in syr. Schr.'], [{'name': 'Martin, Annik', 'role': 'oth', 'gnd': '(DE-588)123303575'}], [], 'BV002729566', 'Historia acephala'])
# dict_values(['BV001241575', ['ita'], [{'name': 'Valenza Mele, Nazarena', 'role': 'Verfasser', 'gnd': '(DE-588)137071027'}], 'Catalogo delle lucerne in bronzo', 'Nazarena Valenza Mele. Museo Nazionale Archeologico di Napoli', 'Roma', 'Museo Nazionale Archeologico di Napoli', '1981 [erschienen] 1983', 'XII, 176 S., [64] Bl.', 'zahlr. Ill.', ['Literaturverz. S. 168 - 170'], [{'word': 'Museo archeologico nazionale di Napoli', 'type': 'b', 'gnd': '(DE-588)1053223-7'}, {'word': 'Bronzelampe', 'type': 's', 'gnd': '(DE-588)4231313-2'}]])
# dict_values(['BV001242530', ['ger'], [{'name': 'Graf, Fritz', 'role': 'Verfasser', 'gnd': '(DE-588)136674046'}], 'Nordionische Kulte', 'religionsgeschichtliche und epigraphische Untersuchungen zu den Kulten von Chios, Erythrai, Klazomenai und Phokaia', 'Fritz Graf', 'Rom', 'Schweizer. Inst.', '1985', 'XX, 490 S.', 'Ill., Kt.', [{'word': 'Ionien', 'type': 'g', 'gnd': '(DE-588)4253742-3'}, {'word': 'Kult', 'type': 's', 'gnd': '(DE-588)4033535-5'}], 'BV001887262', 'Bibliotheca Helvetica Romana'])
# dict_values(['BV001242707', ['ger'], 'Kostbarkeiten der Deutschen Staatsbibliothek', 'hrsg. von Hans-Erich Teitge ... Aufnahmen: Volkmar Herre', 'Wiesbaden', 'Reichert', '1986', '269 S.', 'zahlr. Ill., Kt., Notenbeisp.', [{'name': 'Teitge, Hans-Erich', 'role': 'oth', 'gnd': '(DE-588)122829190'}, {'name': 'Herre, Volkmar', 'role': 'oth', 'gnd': '(DE-588)119373912'}], [{'word': 'Deutsche Staatsbibliothek', 'type': 'b', 'gnd': '(DE-588)1011355-1'}, {'word': 'Zimelie', 'type': 's', 'gnd': '(DE-588)4129995-4'}]])
# dict_values(['BV001242868', ['eng'], [{'name': 'Holmes, George', 'role': 'Verfasser', 'gnd': '(DE-588)172142075'}], 'Florence, Rome and the origins of the Renaissance', 'Oxford', 'Clarendon Pr.', '1986', 'XIV, 273 S.', 'Ill.', [{'word': 'Florenz', 'type': 'g', 'gnd': '(DE-588)4017581-9'}, {'word': 'Kunst', 'type': 's', 'gnd': '(DE-588)4114333-4'}]])
# dict_values(['BV001243076', ['swe'], [{'name': 'Lundgren, Jytte', 'role': 'Verfasser'}], 'Det heliga Korsets historia', 'tolkningar av Piero della Francescas muralmålningar i Bacci-kapellet', 'Göteborg', 'Konstvetenskapliga Inst., Univ.', '1986', '100 S.', 'Ill.', [{'word': 'Piero (della Francesca)', 'date': '1416-1492', 'type': 'p', 'gnd': '(DE-588)118524577'}, {'word': 'San Francesco', 'type': 'g', 'gnd': '(DE-588)4223066-4'}, {'word': 'Freskomalerei', 'type': 's', 'gnd': '(DE-588)4071463-9'}]])
# dict_values(['BV001244439', ['eng'], [{'name': 'Maiorino, Giancarlo', 'role': 'Verfasser'}], 'Adam, new born and perfect', 'the Renaissance promise of eternity', 'Giancarlo Maiorino', 'Bloomington u.a.', 'Indiana Univ. Pr.', '1987', 'X, 157 S.', 'zahlr. Ill.', [{'word': 'Ästhetik', 'type': 's', 'gnd': '(DE-588)4000626-8'}, {'word': 'Italien', 'type': 'g', 'gnd': '(DE-588)4027833-5'}, {'word': 'Michelangelo (Buonarroti)', 'date': '1475-1564', 'type': 'p', 'gnd': '(DE-588)118582143'}]])
# dict_values(['BV001244576', ['dut'], [{'name': 'Blaauw, Sible de', 'role': 'Verfasser', 'gnd': '(DE-588)140106626'}], 'Cultus et decor', 'liturgie en architectuur in laatantiek en middeleeuws Rome, Basilica Salvatoris Sanctae Mariae Sancti Petri', 'door Sible Lambertus de Blaauw', 'Delft', 'Eburon', '1987', '671 S.', ['Zugl.: Leiden, Rijksuniv., Diss.'], [{'word': 'San Giovanni in Laterano', 'type': 'g', 'gnd': '(DE-588)4124075-3'}, {'word': 'Liturgie', 'type': 's', 'gnd': '(DE-588)4036050-7'}]])
# dict_values(['BV001245096', ['ger'], 'Landesausstellung Niedersachsen 1985 Stadt im Wandel, Kunst und Kultur des Bürgertums in Norddeutschland 1150 - 1650', 'Ausstellungskatalog ; Braunschweig, 24. August - 24. November, Braunschweig. Landesmuseum (Vieweghaus), Herzog-Anton-Ulrich-Museum (Burg Dankwarderode) u. Dom am Burgplatz', 'hrsg. von Cord Meckseper', '2', 'Stuttgart-Bad Cannstatt', 'Cantz', '1985', 'S. 689 - 1407', 'zahlr. Ill., graph. Darst., Kt.', [{'name': 'Meckseper, Cord', 'role': 'oth', 'gnd': '(DE-588)120353229'}], []])
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
id : record.get('id')
language : record.get('lang')[0]

# %% [markdown]
# # Json to csv

# %%
input_path = 'data/01.json'
output_path = 'data/out_01.csv'

with open(path, encoding="utf8") as f: 
    data = json.load(f)
with open(output_path, 'w', encoding='utf8') as out: 
    writer = csv.writer(out)
    
    #Write header row: 
    writer.writerow(columns.values())
    
    for record in data['records'].values():
        
        row = [
            record.get('001'),
            record.get('041', {}).get('a'), 
            record.get('049'),
            #list of values for 1XX values 
            record.get('100',{}).get('a'),
            record.get('110',{}).get('a'),
            record.get('111',{}).get('a'),
            record.get('245',{}).get('a'),
            record.get('264',{}).get('a'),
            record.get('300',{}).get('a'),
            #need to get a list of values for each of these
            record.get('600',{}).get('a'),
            record.get('610',{}).get('a'),
            record.get('611',{}).get('a'),
            record.get('630',{}).get('a'),
            record.get('647',{}).get('a'),
            record.get('648',{}).get('a'),
            record.get('650',{}).get('a'),
            record.get('651',{}).get('a'),
        ]
        writer.writerow(row)

# %%
df = pd.read_csv(output_path)

# %%
df
# Out:
#                id language_code         holdings            author_person  \
# 0     BV000023649           ger   {'a': 'DE-Y7'}                      NaN
# 1     BV000024214           ger  {'a': 'DE-188'}         Schlink, Wilhelm
# 2     BV000024767           ger   {'a': 'DE-Y3'}        Burckhardt, Jacob
# 3     BV000025578           ger   {'a': 'DE-Y2'}           Herzog, Werner
# 4     BV000026429           ita   {'a': 'DE-Y2'}            Rotili, Mario
# ...           ...           ...              ...                      ...
# 6003  BV001554556           ita   {'a': 'DE-Y2'}      Angeloni, Francesco
# 6004  BV001554561           ita   {'a': 'DE-Y2'}        Angelotti, Pompeo
# 6005  BV001554563           ita   {'a': 'DE-Y2'}     Angelucci, Giulio A.
# 6006  BV001554686           ita   {'a': 'DE-83'}            Arnaldi, Enea
# 6007  BV001555100           ger   {'a': 'DE-Y2'}  Arnold, Ignaz Ferdinand
#
#                                        author_corporate author_uniform  \
# 0     Schiller-Nationalmuseum und Deutsches Literatu...            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 6003                                                NaN            NaN
# 6004                                                NaN            NaN
# 6005                                                NaN            NaN
# 6006                                                NaN            NaN
# 6007                                                NaN            NaN
#
#                                                   title        publication  \
# 0     Deutsches Literaturarchiv, Schiller-Nationalmu...  Marbach a. Neckar
# 1     Jacob Burckhardt und die Kunsterwartung im Vor...          Wiesbaden
# 2                       Über das Studium der Geschichte            München
# 3                                          Fitzcarraldo       München u.a.
# 4     Filippo Raguzzini nel terzo centenario della n...             Napoli
# ...                                                 ...                ...
# 6003                                  Historia di Terni               Roma
# 6004                  Descrittione della città di Rieti               Roma
# 6005  Stanze dell'Abate Angelucci con documenti e no...               Pisa
# 6006  Delle Basiliche antiche e specialmente di quel...            Vicenza
# 6007  Anleitung zur Beurtheilung der Kunstwerke der ...          Altenburg
#
#                              physical_description   subject_personal  \
# 0                                      181, 16 S.                NaN
# 1                                           27 S.  Burckhardt, Jacob
# 2                                          582 S.  Burckhardt, Jacob
# 3                                          164 S.     Herzog, Werner
# 4                                           69 S.  Rauzzini, Filippo
# ...                                           ...                ...
# 6003                                       289 S.                NaN
# 6004                                       123 S.                NaN
# 6005                                       254 S.                NaN
# 6006                       VIII, CXXXV S., 8 Taf.   Palladio, Andrea
# 6007  XIV Seiten, 1 ungezähltes Blatt, 334 Seiten                NaN
#
#                          subject_corporate subject_meeting  \
# 0        Deutsches Literaturarchiv Marbach             NaN
# 1                                      NaN             NaN
# 2                                      NaN             NaN
# 3                                      NaN             NaN
# 4                                      NaN             NaN
# ...                                    ...             ...
# 6003                                   NaN             NaN
# 6004                                   NaN             NaN
# 6005                                   NaN             NaN
# 6006  Basilica palladiana (Vicenza, Italy)             NaN
# 6007                                   NaN             NaN
#
#      subject_uniform_title  subject_named_event subject_chronological  \
# 0                      NaN                  NaN            Geschichte
# 1                      NaN                  NaN  Geschichte 1830-1848
# 2                      NaN                  NaN        Weltgeschichte
# 3             Fitzcarraldo                  NaN                   NaN
# 4                      NaN                  NaN                   NaN
# ...                    ...                  ...                   ...
# 6003                   NaN                  NaN                   NaN
# 6004                   NaN                  NaN                   NaN
# 6005                   NaN                  NaN  Geschichte 1250-1816
# 6006                   NaN                  NaN      Geschichte -1580
# 6007                   NaN                  NaN                   NaN
#
#            subject_topical subject_geographic
# 0                      NaN                NaN
# 1         Kunstbetrachtung        Deutschland
# 2           Weltgeschichte                NaN
# 3           German fiction                NaN
# 4     Architecture, Rococo            Italien
# ...                    ...                ...
# 6003            Geschichte      Terni (Italy)
# 6004                   NaN      Rieti (Italy)
# 6005                   NaN             Arezzo
# 6006    Architekturtheorie            Vicenza
# 6007           Kunstkritik                NaN
#
# [6008 rows x 17 columns]
